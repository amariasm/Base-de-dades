# %% [markdown]
# # Sprint 1: Tasca M1 T01

# %% [markdown]
# ## Exercici 1
#
# #### A partir dels documents adjunts (estructura i dades), crea una base de dades amb MySQL.
# #### Mostra les característiques principals de l'esquema creat i explica les diferents taules i variables que hi ha.

# %% [markdown]
# #### A) Características principales del Esquema

# %% [markdown]
# La Base de Datos "Movies" consta de cinco tablas, con los campos siguientes:
#
# * tb_genre:
#             1- genre_id: Índice del género de la película (*) (1,2,3....)
#             2- genre_name: Tipo de género de la película. (1. Acción, 2. Ciencia Ficción, 3. Comedia,etc..)
#             3- created_by_user: Creador de la tabla
#             4- created_date: Fecha de creación
#             5- update_date: Fecha grabación
#
# * tb_movie:
#             1- movie_id: Índice de peliculas (**) (1,2,3...)
#             2- movie_title: Título de la película
#             3- movie_date: Fecha de la película
#             4- movie_format: formato de la película. (Film ó Digital)
#             5- movie_genre_id: código del género de la película (*) (1, 2, 3....)
#             6- created_by_user: Creador de la tabla
#             7- created_date: Fecha de creación
#             8- update_date: Fecha grabació
#
# * tb_movie_person:
#             1- movie_id: Índice de peliculas (**)
#             2- person_id: Índice de personas (***)
#             3- role_id: Índice de roles (****) (1 a 5)
#             4- movie_award_ind: premios
#             5- created_by_user: Creador de la tabla
#             6- created_date: Fecha de creación
#             7- update_date: Fecha grabación
#
# * tb_person:
#             1- person_id:Índice de persona (***) (1,2,3...)
#             2- person_name: Nombre de la persona
#             3- person_country: nacionalidad
#             4- person_dob: fecha de nacimiento
#             5- person_dod: fecha de fallecimiento
#             6- person_parent_id: Índice de parent
#             7- created_by_user: Creador de la tabla
#             8- created_date: Fecha de creación
#             9- update_date: Fecha grabación
#
# * tb_role:
#             1- role_id: Índice de roles (****) (1 a 5)
#             2- role_name: nombre de los roles (1. Actor, 2. Director, 3. Productor, 4. Guionista y 5. Música)
#             3- created_by_user: Creador de la tabla
#             4- created_date: Fecha de creación
#             5- update_date: Fecha grabación
#
# (*....) Los asteríscos indican las relaciones de dependencia entre las diferentes tablas de la base de datos

# %% [markdown]
# ![EsqBBDDMovies2.png](attachment:7718db4a-306b-4be7-a24d-f348941a0f01.png)

# %% [markdown]
# #### B) Capturas de Pantallas de las diferentes tablas y datos de Movies

# %% [markdown]
# #### B.1) Tabla de Géneros: Tabla_tb_genre

# %% [markdown]
# ![tb_genre_tabla.png](attachment:1a8a3981-d6ad-4ae2-949d-0f4e6871b7fd.png)

# %% [markdown]
# #### B.1.1) Tabla de Géneros: Datos_tb_genre

# %% [markdown]
# ![tb_genre_datos.png](attachment:8bd3dfb0-1ffc-4909-9c2d-190e19a954bc.png)

# %% [markdown]
# #### B.1.2) Tabla de Géneros: Dades a introduir.txt_tb_genre

# %% [markdown]
# ![tb_genre_datos_a_introducir.png](attachment:6b83aff2-a6d6-400c-a000-b2ca24594bd0.png)

# %% [markdown]
# #### B.2) Tabla de películass: Tabla_tb_movie

# %% [markdown]
# ![tb_movie_tablas.png](attachment:0bc08777-759b-4287-b9b7-10e1bb6477dc.png)

# %% [markdown]
# #### B.3) Tabla de películas y Personas: Tabla_tb_movie_person

# %% [markdown]
# ![tb_movie_person.png](attachment:6075af94-0114-432b-b987-87c82ba2d69d.png)

# %% [markdown]
# #### B.4) Tabla de Personas: Tabla_tb_person

# %% [markdown]
# ![tb_person_tabla.png](attachment:7c9a2c25-6ef2-4eb6-953f-3d12fc1f17bb.png)

# %% [markdown]
# #### B.5) Tabla de Roles: Tabla_tb_role

# %% [markdown]
# ![tb_role_tabla.png](attachment:944a654b-7db3-4a9a-90e9-6798719f5837.png)

# %% [markdown]
# #### C) Conexión MSQL - Python

# %%
import mysql.connector
import pandas as pd
import sqlalchemy

# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="hectorete1"
)

print(mydb)

# %% [markdown]
# #### C.1) Tabla de Géneros de Películas

# %%
engine = sqlalchemy.create_engine('mysql+mysqlconnector://root:hectorete1@localhost/movies')
data_genre = pd.read_sql_table("tb_genre", engine)
# check first rows of thcursor=connection.cursor()is table 
data_genre
# Out:
#     genre_id       genre_name created_by_user created_date updated_date
# 0          1           Acción         OS_SGAD          NaT          NaT
# 1          2  Ciencia Ficción         OS_SGAD          NaT          NaT
# 2          3          Comedia         OS_SGAD          NaT          NaT
# 3          4            Drama         OS_SGAD          NaT          NaT
# 4          5         Fantasía         apermag          NaT          NaT
# 5          6        Melodrama         apermag   2018-09-01   2018-09-27
# 6          7          Musical         OS_SGAD          NaT          NaT
# 7          8          Romance         OS_SGAD          NaT          NaT
# 8          9         Suspense         OS_SGAD          NaT          NaT
# 9         10           Terror         OS_SGAD          NaT          NaT
# 10        11           Bélico         OS_SGAD          NaT          NaT
# 11        69       Documental         OS_SGAD          NaT          NaT

# %% [markdown]
# #### C.2) Tabla de Películas

# %%
data_movie = pd.read_sql_table("tb_movie", engine)
# check first rows of this table 
data_movie
# Out:
#     movie_id                           movie_title movie_date movie_format  \
# 0          1                        Apocalypse Now 1979-05-10         Film
# 1          2     Star Wars:Episode IV - A New Hope 1977-05-25         Film
# 2          3  Indiana Jones and the Temple of Doom 1984-05-08         Film
# 3          4                          The Terminal 2004-06-18      Digital
# 4          5                                  Jaws 1975-01-01         Film
# 5          6               ET The Extraterrestrial 1982-07-25         Film
# 6          7                                Psycho 1960-05-06         Film
# 7          8                 Ocho Apellidos Vascos 2014-03-14      Digital
# 8          9              Ocho Apellidos Catalanes 2016-06-09      Digital
# 9         10               El otro lado de la cama 2002-09-04      Digital
# 10        12                   El dia de la bestia 1994-12-25         Film
# ...

# %% [markdown]
# #### C.3) Tabla de ID ( Películas - Personas - Roles)

# %%
data_movie_person = pd.read_sql_table("tb_movie_person", engine)
# check first rows of this table 
data_movie_person
# Out:
#     movie_id  person_id  role_id movie_award_ind created_by_user created_date  \
# 0          1          1        2               Y         OS_SGAD          NaT
# 1          1          1        3               N         OS_SGAD          NaT
# 2          1          1        5               N         OS_SGAD          NaT
# 3          1          2        5               N         OS_SGAD          NaT
# 4          1          3        1               N         OS_SGAD          NaT
# 5          1          4        1               N         OS_SGAD          NaT
# 6          1          5        1               Y         OS_SGAD          NaT
# 7          1          6        1               N         OS_SGAD          NaT
# 8          1         41        1               N         OS_SGAD          NaT
# 9          2          6        1               N         OS_SGAD          NaT
# 10         2          7        2               Y         OS_SGAD          NaT
# ...

# %% [markdown]
# #### C.4) Tabla de Personas

# %%
data_person = pd.read_sql_table("tb_person", engine)
# check first rows of this table 
data_person
# Out:
#     person_id              person_name  person_country person_dob person_dod  \
# 0           1     Francis Ford Coppola   United States 1939-04-07        NaT
# 1           2          Carmine Coppola   United States 1945-07-08        NaT
# 2           3            Marlon Brando   United States 1924-04-03 2004-07-01
# 3           4            Robert Duvall   United States 1931-01-05        NaT
# 4           5             Martin Sheen   United States 1940-08-03        NaT
# 5           6            Harrison Ford   United States 1942-07-13        NaT
# 6           7             George Lucas   United States 1944-05-14        NaT
# 7           8               Gary Kurtz   United States 1940-07-27        NaT
# 8           9         Steven Spielberg   United States 1946-12-18        NaT
# 9          10            John Williams   United States 1928-08-08        NaT
# 10         11                Tom Hanks   United States 1956-07-09        NaT
# ...

# %% [markdown]
# #### C.5) Tabla de Roles

# %%
data_role = pd.read_sql_table("tb_role", engine)
# check first rows of this table 
data_role
# Out:
#    role_id  role_name created_by_user created_date updated_date
# 0        1      Actor         OS_SGAD          NaT          NaT
# 1        2   Director         OS_SGAD          NaT          NaT
# 2        3  Productor         OS_SGAD          NaT          NaT
# 3        4  Guionista         OS_SGAD          NaT          NaT
# 4        5     Música         OS_SGAD          NaT          NaT

# %% [markdown]
# ## Exercici 2
#
# #### Realitza la següent consulta sobre la base de dades acabada de crear:
# * Has d'obtenir el nom, el país i la data de naixement d'aquelles persones per les quals no consti una data de mort
# * i ordenar les dades de la persona més vella a la persona més jove.

# %%
query = '''
SELECT person_name, person_country, person_dob,
       timestampdiff(YEAR, person_dob, current_date) as current_ages
FROM tb_person
WHERE person_dod is null
ORDER BY current_ages desc; 

'''

current_ages_df = pd.read_sql_query(query, engine)
current_ages_df
# Out:
#                person_name person_country  person_dob  current_ages
# 0            John Williams  United States  1928-08-08            93
# 1             Sean Connery       Scotland  1930-07-08            92
# 2               Vera Miles  United States  1929-08-23            92
# 3            Robert Duvall  United States  1931-01-05            91
# 4           Morgan Freeman  United States  1935-10-01            86
# 5     Francis Ford Coppola  United States  1939-04-07            83
# 6               Gary Kurtz  United States  1940-07-27            82
# 7             Martin Sheen  United States  1940-08-03            81
# 8            Harrison Ford  United States  1942-07-13            80
# 9             George Lucas  United States  1944-05-14            78
# 10         Carmine Coppola  United States  1945-07-08            77
# 11        Steven Spielberg  United States  1946-12-18            75
# 12             Tim Robbins  United States  1949-06-07            73
# ...

# %% [markdown]
# ## Exercici 3
# #### Realitza la següent consulta :
#
# * Has d'obtenir el nom del gènere i el nombre total de pel·lícules d'aquest gènere i ordenar-ho per ordre descendent de nombre total de pel·lícules.

# %%
query = '''
SELECT genre_name, COUNT(*) movie_count

FROM tb_movie
INNER JOIN tb_genre
ON
tb_movie.movie_genre_id = tb_genre.genre_id
GROUP BY genre_name
ORDER BY movie_count desc; 

'''

join_df = pd.read_sql_query(query, engine)
join_df.head(11)
# Out:
#         genre_name  movie_count
# 0  Ciencia Ficción            4
# 1          Comedia            3
# 2         Suspense            2
# 3            Drama            2
# 4          Romance            1
# 5           Terror            1
# 6           Bélico            1
# 7         Fantasía            1

# %% [markdown]
# ## Exercici 4
#
# #### Realitza la següent consulta:
#
# * Has d'obtenir, per a cada persona, el seu nom i el nombre màxim de rols diferents que ha tingut en una mateixa pel·lícula.
#
# * Posteriorment, mostra únicament aquelles persones que hagin assumit més d'un rol en una mateixa pel·lícula.

# %%
query = '''
SELECT person_name, role_name, movie_title

FROM
    (((tb_movie_person
    INNER JOIN tb_person ON tb_movie_person.person_id = tb_person.person_id)
    INNER JOIN tb_role ON tb_movie_person.role_id = tb_role.role_id)
    INNER JOIN tb_movie ON tb_movie_person.movie_id = tb_movie.movie_id)

ORDER BY person_name asc; 

'''

join2_df = pd.read_sql_query(query, engine)
join2_df
# Out:
#                 person_name  role_name                           movie_title
# 0   Alfred Joseph Hitchcock  Productor                                Psycho
# 1   Alfred Joseph Hitchcock      Actor                                Psycho
# 2   Alfred Joseph Hitchcock   Director                                Psycho
# 3           Anthony Perkins   Director                                Psycho
# 4              Carmen Machi      Actor              Ocho Apellidos Catalanes
# 5              Carmen Machi      Actor                 Ocho Apellidos Vascos
# 6           Carmine Coppola     Música                        Apocalypse Now
# 7      Catherine Zeta-Jones      Actor                          The Terminal
# 8             Charlie Sheen      Actor                        Apocalypse Now
# 9                Clara Lago      Actor              Ocho Apellidos Catalanes
# 10               Clara Lago      Actor                 Ocho Apellidos Vascos
# ...

# %% [markdown]
# * En la salida figura Anthony Perkins como Director en Psycho, cuando el rol fué Actor, pero hemos verificado que el código de rol correspondiente al person_id 14 en la tabla de movie_person es: 2, que corresponde al de Director, así que es un error de codificación en tb_movie_person original.

# %%
query = '''
SELECT movie_title, person_name, COUNT(*) role_count

FROM
    (((tb_movie_person
    INNER JOIN tb_person ON tb_movie_person.person_id = tb_person.person_id)
    INNER JOIN tb_role ON tb_movie_person.role_id = tb_role.role_id)
    INNER JOIN tb_movie ON tb_movie_person.movie_id = tb_movie.movie_id)
    

GROUP BY movie_title, person_name
HAVING role_count >1  
ORDER BY movie_title asc
 
;


'''

join2_df = pd.read_sql_query(query, engine)
join2_df
# Out:
#                             movie_title              person_name  role_count
# 0                        Apocalypse Now     Francis Ford Coppola           3
# 1                            Braveheart               Mel Gibson           2
# 2  Indiana Jones and the Temple of Doom             George Lucas           2
# 3                                Psycho  Alfred Joseph Hitchcock           3
# 4                          The Terminal         Steven Spielberg           2

# %% [markdown]
# ## Exercici 5
# #### Realitza la següent operació sobre la base de dades acabada de crear:
#
# * Has de crear un nou gènere anomenat "Documental" el qual tingui com a identificador el nombre 69.

# %%
# Import pymysql module
#import # Import pymysql module
import pymysql

# %%
# Connect to the database
connection = pymysql.connect(host='localhost',
                             user='root',
                             password='hectorete1',
                             db='movies')

# %%
cursor = connection.cursor()

# %%
sql = "INSERT INTO `movies.tb_genre` (genre_id, genre_name) VALUES (69, 'Documental')"


# the connection is not autocommited by default. So we must commit to save our changes.
connection.commit()

# %%
engine = sqlalchemy.create_engine('mysql+mysqlconnector://root:hectorete1@localhost/movies')
data_genre = pd.read_sql_table("tb_genre", engine)
# check first rows of thcursor=connection.cursor()is table 
data_genre
# Out:
#     genre_id       genre_name created_by_user created_date updated_date
# 0          1           Acción         OS_SGAD          NaT          NaT
# 1          2  Ciencia Ficción         OS_SGAD          NaT          NaT
# 2          3          Comedia         OS_SGAD          NaT          NaT
# 3          4            Drama         OS_SGAD          NaT          NaT
# 4          5         Fantasía         apermag          NaT          NaT
# 5          6        Melodrama         apermag   2018-09-01   2018-09-27
# 6          7          Musical         OS_SGAD          NaT          NaT
# 7          8          Romance         OS_SGAD          NaT          NaT
# 8          9         Suspense         OS_SGAD          NaT          NaT
# 9         10           Terror         OS_SGAD          NaT          NaT
# 10        11           Bélico         OS_SGAD          NaT          NaT
# 11        69       Documental         OS_SGAD          NaT          NaT

# %%
# Close the connection
connection.close()

# %% [markdown]
# ##  Exercici 6
# #### Fes la següent operació sobre la base de dades acabada de crear:
# * Elimina la pel·lícula "La Gran Familia Española" de la base de dades.

# %%
import mysql.connector

mydb = mysql.connector.connect(host="localhost",
                               user="root",
                               password="hectorete1",
                               database="movies")

# %%
mycursor = mydb.cursor()

# %%
sql=" ALTER TABLE `tb_movie_person` DROP CONSTRAINT `fk_movper_movie`;"

# %%
mycursor.execute(sql)

# %%
sql=" ALTER TABLE `tb_movie_person` ADD CONSTRAINT `fk_movper_movie` FOREIGN KEY (movie_id) REFERENCES movies.tb_movie (movie_id) ON DELETE CASCADE;"

# %%
mycursor.execute(sql)

# %%
sql ="DELETE FROM tb_movie WHERE tb_movie.movie_title='La Gran Familia Española'"

# %%
mycursor.execute(sql)

# %%
# Close the connection
mydb.close()

# %%
data_movie = pd.read_sql_table("tb_movie", engine)
# check first rows of this table 
data_movie
# Out:
#     movie_id                           movie_title movie_date movie_format  \
# 0          1                        Apocalypse Now 1979-05-10         Film
# 1          2     Star Wars:Episode IV - A New Hope 1977-05-25         Film
# 2          3  Indiana Jones and the Temple of Doom 1984-05-08         Film
# 3          4                          The Terminal 2004-06-18      Digital
# 4          5                                  Jaws 1975-01-01         Film
# 5          6               ET The Extraterrestrial 1982-07-25         Film
# 6          7                                Psycho 1960-05-06         Film
# 7          8                 Ocho Apellidos Vascos 2014-03-14      Digital
# 8          9              Ocho Apellidos Catalanes 2016-06-09      Digital
# 9         10               El otro lado de la cama 2002-09-04      Digital
# 10        12                   El dia de la bestia 1994-12-25         Film
# ...

# %% [markdown]
# * Se ha eliminado la película 11: "La Gran Familia Española"

# %% [markdown]
# ## Exercici 7
#
# #### Realitza la següent operació sobre la base de dades acabada de crear:
#
# * Canvia el gènere de la pel·lícula "Ocho apellidos catalanes" perquè consti com a comèdia i no com a romàntica.

# %%
mydb = mysql.connector.connect(host="localhost",
                               user="root",
                               password="hectorete1",
                               database="movies")

mycursor = mydb.cursor()

sql = "UPDATE tb_movie SET  movie_genre_id= 3 WHERE  movie_title='Ocho Apellidos Catalanes'"

mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "registros afectado/s")
# Out:
# 0 registros afectado/s

# %%
data_movie = pd.read_sql_table("tb_movie", engine)
# check first rows of this table 
data_movie
# Out:
#     movie_id                           movie_title movie_date movie_format  \
# 0          1                        Apocalypse Now 1979-05-10         Film
# 1          2     Star Wars:Episode IV - A New Hope 1977-05-25         Film
# 2          3  Indiana Jones and the Temple of Doom 1984-05-08         Film
# 3          4                          The Terminal 2004-06-18      Digital
# 4          5                                  Jaws 1975-01-01         Film
# 5          6               ET The Extraterrestrial 1982-07-25         Film
# 6          7                                Psycho 1960-05-06         Film
# 7          8                 Ocho Apellidos Vascos 2014-03-14      Digital
# 8          9              Ocho Apellidos Catalanes 2016-06-09      Digital
# 9         10               El otro lado de la cama 2002-09-04      Digital
# 10        12                   El dia de la bestia 1994-12-25         Film
# ...

# %%
query = '''
SELECT movie_title,genre_name

FROM tb_movie
INNER JOIN tb_genre
ON
tb_movie.movie_genre_id = tb_genre.genre_id

ORDER BY movie_title asc; 

'''

join_df = pd.read_sql_query(query, engine)
join_df
# Out:
#                              movie_title       genre_name
# 0                         Apocalypse Now           Bélico
# 1                           Blade Runner  Ciencia Ficción
# 2                             Braveheart            Drama
# 3                    El dia de la bestia  Ciencia Ficción
# 4                El otro lado de la cama          Romance
# 5                ET The Extraterrestrial         Fantasía
# 6   Indiana Jones and the Temple of Doom  Ciencia Ficción
# 7                                   Jaws           Terror
# 8             Las brujas de Zugarramurdi         Suspense
# 9               Ocho Apellidos Catalanes          Comedia
# 10                 Ocho Apellidos Vascos          Comedia
# 11                                Psycho         Suspense
# 12     Star Wars:Episode IV - A New Hope  Ciencia Ficción
# 13              The Shawshank Redemption            Drama
# 14                          The Terminal          Comedia
